# %% [markdown]
# <a href="https://colab.research.google.com/github/vavilala-yash/irisflowerclassification/blob/main/MLiris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7aaff60-9f81-4271-aca9-8ed1f4d0de2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7aaff60-9f81-4271-aca9-8ed1f4d0de2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
iris = pd.read_csv(io.BytesIO(uploaded['iris.csv']))

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length   petal_width           class
# 0             5.1          3.5           1.4           0.2     iris_setosa
# 1             4.9          3.0           1.4           0.2     iris_setosa
# 2             4.7          3.2           1.3           0.2     iris_setosa
# 3             4.6          3.1           1.5           0.2     iris_setosa
# 4             5.0          3.6           1.4           0.2     iris_setosa
# ..            ...          ...           ...           ...             ...
# 145           6.7          3.0           5.2           2.3  iris_virginica
# 146           6.3          2.5           5.0           1.9  iris_virginica
# 147           6.5          3.0           5.2           2.0  iris_virginica
# 148           6.2          3.4           5.4           2.3  iris_virginica
# 149           5.9          3.0           5.1           1.8  iris_virginica
#
# [150 rows x 5 columns]

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length   petal_width
# count    150.000000   150.000000    150.000000    150.000000
# mean       5.843333     3.054000      3.758667      1.198667
# std        0.828066     0.433594      1.764420      0.763161
# min        4.300000     2.000000      1.000000      0.100000
# 25%        5.100000     2.800000      1.600000      0.300000
# 50%        5.800000     3.000000      4.350000      1.300000
# 75%        6.400000     3.300000      5.100000      1.800000
# max        7.900000     4.400000      6.900000      2.500000

# %%
x=iris.drop(columns=['class'])
x
# Out:
#      sepal_length  sepal_width  petal_length   petal_width
# 0             5.1          3.5           1.4           0.2
# 1             4.9          3.0           1.4           0.2
# 2             4.7          3.2           1.3           0.2
# 3             4.6          3.1           1.5           0.2
# 4             5.0          3.6           1.4           0.2
# ..            ...          ...           ...           ...
# 145           6.7          3.0           5.2           2.3
# 146           6.3          2.5           5.0           1.9
# 147           6.5          3.0           5.2           2.0
# 148           6.2          3.4           5.4           2.3
# 149           5.9          3.0           5.1           1.8
#
# [150 rows x 4 columns]

# %%
print(x.shape)
# Out:
# (150, 4)

# %%
y=iris['class']
y
# Out:
# 0         iris_setosa
# 1         iris_setosa
# 2         iris_setosa
# 3         iris_setosa
# 4         iris_setosa
#             ...
# 145    iris_virginica
# 146    iris_virginica
# 147    iris_virginica
# 148    iris_virginica
# 149    iris_virginica
# Name: class, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.4)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length   petal_width
# 105           7.6          3.0           6.6           2.1
# 146           6.3          2.5           5.0           1.9
# 94            5.6          2.7           4.2           1.3
# 140           6.7          3.1           5.6           2.4
# 132           6.4          2.8           5.6           2.2
# ..            ...          ...           ...           ...
# 143           6.8          3.2           5.9           2.3
# 147           6.5          3.0           5.2           2.0
# 45            4.8          3.0           1.4           0.3
# 73            6.1          2.8           4.7           1.2
# 102           7.1          3.0           5.9           2.1
#
# [90 rows x 4 columns]

# %%
y_train
# Out:
# 105     iris_virginica
# 146     iris_virginica
# 94     iris_versicolor
# 140     iris_virginica
# 132     iris_virginica
#             ...
# 143     iris_virginica
# 147     iris_virginica
# 45         iris_setosa
# 73     iris_versicolor
# 102     iris_virginica
# Name: class, Length: 90, dtype: object

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length   petal_width
# 12            4.8          3.0           1.4           0.1
# 56            6.3          3.3           4.7           1.6
# 131           7.9          3.8           6.4           2.0
# 53            5.5          2.3           4.0           1.3
# 15            5.7          4.4           1.5           0.4
# 49            5.0          3.3           1.4           0.2
# 64            5.6          2.9           3.6           1.3
# 107           7.3          2.9           6.3           1.8
# 70            5.9          3.2           4.8           1.8
# 0             5.1          3.5           1.4           0.2
# 1             4.9          3.0           1.4           0.2
# 137           6.4          3.1           5.5           1.8
# 122           7.7          2.8           6.7           2.0
# 13            4.3          3.0           1.1           0.1
# 4             5.0          3.6           1.4           0.2
# ...

# %%
y_test
# Out:
# 12         iris_setosa
# 56     iris_versicolor
# 131     iris_virginica
# 53     iris_versicolor
# 15         iris_setosa
# 49         iris_setosa
# 64     iris_versicolor
# 107     iris_virginica
# 70     iris_versicolor
# 0          iris_setosa
# 1          iris_setosa
# 137     iris_virginica
# 122     iris_virginica
# 13         iris_setosa
# 4          iris_setosa
# 2          iris_setosa
# 46         iris_setosa
# 32         iris_setosa
# 31         iris_setosa
# 34         iris_setosa
# 57     iris_versicolor
# 81     iris_versicolor
# 16         iris_setosa
# 111     iris_virginica
# 139     iris_virginica
# 26         iris_setosa
# 68     iris_versicolor
# 117     iris_virginica
# 50     iris_versicolor
# 29         iris_setosa
# 71     iris_versicolor
# 85     iris_versicolor
# 77     iris_versicolor
# 80     iris_versicolor
# 33         iris_setosa
# 3          iris_setosa
# 27         iris_setosa
# 113     iris_virginica
# 69     iris_versicolor
# 103     iris_virginica
# ...

# %%
from sklearn import neighbors
classifier1=neighbors.KNeighborsClassifier()

# %%
classifier1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predictions=classifier1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.9833333333333333

# %%
from sklearn import tree
classifier2=tree.DecisionTreeClassifier()

# %%
classifier2.fit(x_train,y_train)
predictions=classifier2.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.9666666666666667
